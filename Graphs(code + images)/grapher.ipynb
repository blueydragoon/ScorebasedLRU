# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data
data = pd.read_csv('RECE1.csv')
data2 = pd.read_csv('LRFU1.csv')

# Plot
plt.figure(figsize=(10,10))
plt.plot(data['size'], data[' hitRatio'],label='RECE1')
plt.plot(data2['size'], data2[' hitRatio'],label='LRFU1')
#plt.xticks(data['size'], data[' hits'])
plt.legend()
plt.xlabel('size')
plt.ylabel('hitRatio')
plt.show()
plt.savefig('name.png')
